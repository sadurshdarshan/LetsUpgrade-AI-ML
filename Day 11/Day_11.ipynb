# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv('general_data.csv') 
dataset1.head()
# Out:
#    Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0   51        No  ...                       0                    0
# 1   31       Yes  ...                       1                    4
# 2   32        No  ...                       0                    3
# 3   38        No  ...                       7                    5
# 4   32        No  ...                       0                    4
#
# [5 rows x 24 columns]

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset.isnull()
# Out:
#         Age  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0     False      False  ...                    False                 False
# 1     False      False  ...                    False                 False
# 2     False      False  ...                    False                 False
# 3     False      False  ...                    False                 False
# 4     False      False  ...                    False                 False
# ...     ...        ...  ...                      ...                   ...
# 4405  False      False  ...                    False                 False
# 4406  False      False  ...                    False                 False
# 4407  False      False  ...                    False                 False
# 4408  False      False  ...                    False                 False
# 4409  False      False  ...                    False                 False
#
# [4410 rows x 24 columns]

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %%
dataset.dropna()
# Out:
#       Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51        No  ...                       0                    0
# 1      31       Yes  ...                       1                    4
# 2      32        No  ...                       0                    3
# 3      38        No  ...                       7                    5
# 4      32        No  ...                       0                    4
# ...   ...       ...  ...                     ...                  ...
# 4404   29        No  ...                       1                    5
# 4405   42        No  ...                       0                    2
# 4406   29        No  ...                       0                    2
# 4407   25        No  ...                       1                    2
# 4408   42        No  ...                       7                    8
#
# [4382 rows x 24 columns]

# %%
dataset.drop_duplicates()
# Out:
#       Age Attrition  ... YearsSinceLastPromotion YearsWithCurrManager
# 0      51        No  ...                       0                    0
# 1      31       Yes  ...                       1                    4
# 2      32        No  ...                       0                    3
# 3      38        No  ...                       7                    5
# 4      32        No  ...                       0                    4
# ...   ...       ...  ...                     ...                  ...
# 4405   42        No  ...                       0                    2
# 4406   29        No  ...                       0                    2
# 4407   25        No  ...                       1                    2
# 4408   42        No  ...                       7                    8
# 4409   40        No  ...                       3                    9
#
# [4410 rows x 24 columns]

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
print(dataset1)
# Out:
#                Age  ...  YearsWithCurrManager
# count     8.000000  ...              8.000000
# mean    580.382139  ...            555.836307
# std    1547.475750  ...           1557.325946
# min       9.133301  ...              0.000000
# 25%      27.000000  ...              2.750000
# 50%      36.461905  ...              3.845228
# 75%      47.250000  ...              9.500000
# max    4410.000000  ...           4410.000000
#
# [8 rows x 11 columns]

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mean()
dataset1
# Out:
# Age                          580.382139
# DistanceFromHome             560.037193
# Education                    553.617107
# MonthlyIncome              61086.025186
# NumCompaniesWorked           551.524215
# PercentSalaryHike            563.608579
# TotalWorkingYears            561.382770
# TrainingTimesLastYear        553.511037
# YearsAtCompany               560.016662
# YearsSinceLastPromotion      554.301182
# YearsWithCurrManager         555.836307
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
dataset1
# Out:
# Age                        2.394681e+06
# DistanceFromHome           2.420030e+06
# Education                  2.428033e+06
# MonthlyIncome              3.857002e+09
# NumCompaniesWorked         2.406795e+06
# PercentSalaryHike          2.415503e+06
# TotalWorkingYears          2.407106e+06
# TrainingTimesLastYear      2.428167e+06
# YearsAtCompany             2.420136e+06
# YearsSinceLastPromotion    2.427193e+06
# YearsWithCurrManager       2.425264e+06
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
dataset1
# Out:
#            Age  DistanceFromHome  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0     9.133301          1.000000  ...                      0.0              0.000000
# 1    18.000000          2.000000  ...                      NaN              2.000000
# 2    30.000000          7.000000  ...                      NaN              3.000000
# 3    36.000000          8.105026  ...                      NaN              3.567327
# 4    36.923810          9.192517  ...                      NaN              4.123129
# 5    43.000000         14.000000  ...                      NaN              7.000000
# 6    60.000000         29.000000  ...                      NaN             17.000000
# 7  4410.000000       4410.000000  ...                      NaN           4410.000000
#
# [8 rows x 11 columns]

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
dataset1
# Out:
# Age                        2.827868
# DistanceFromHome           2.828249
# Education                  2.828423
# MonthlyIncome              1.860748
# NumCompaniesWorked         2.828410
# PercentSalaryHike          2.828341
# TotalWorkingYears          2.828096
# TrainingTimesLastYear      2.828420
# YearsAtCompany             2.828061
# YearsSinceLastPromotion    2.828372
# YearsWithCurrManager       2.828364
# dtype: float64

# %%
dataset1=dataset[['Age','DistanceFromHome','Education','MonthlyIncome', 'NumCompaniesWorked', 'PercentSalaryHike','TotalWorkingYears', 'TrainingTimesLastYear', 'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
dataset1
# Out:
# Age                        7.997628
# DistanceFromHome           7.999241
# Education                  7.999981
# MonthlyIncome              4.104953
# NumCompaniesWorked         7.999927
# PercentSalaryHike          7.999633
# TotalWorkingYears          7.998588
# TrainingTimesLastYear      7.999971
# YearsAtCompany             7.998440
# YearsSinceLastPromotion    7.999767
# YearsWithCurrManager       7.999733
# dtype: float64

# %%
plt.boxplot(dataset.EmployeeID)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f630ac13780>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f630aba21d0>,
#   <matplotlib.lines.Line2D at 0x7f630aba2550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f630aba2c50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f630aba28d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f630ac13a90>,
#   <matplotlib.lines.Line2D at 0x7f630ac13e10>]}

# %%
plt.boxplot(dataset.MonthlyIncome)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f630aac1dd8>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f630aad0828>,
#   <matplotlib.lines.Line2D at 0x7f630aad0ba8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f630aad92e8>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f630aad0f28>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f630aad0128>,
#   <matplotlib.lines.Line2D at 0x7f630aad04a8>]}
